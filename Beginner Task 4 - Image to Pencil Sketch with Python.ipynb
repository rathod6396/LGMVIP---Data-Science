# %% [markdown]
# #**LetsGrowMore #November 2021**
#
# #**Author - Parth Kantilal Rathod**
#
# #**Level : Beginner.**
#
# #**Task Title : Image to Pencil Sketch with Python**

# %%
**STEPS**

- **Step 1** - Import Required Libraries
- **Step 2** - Importing Image
- **Step 3** - Converting Image into Grey Scale Image.
- **Step 4** - Inverting the grey scale image
- **Step 5** - Image Smoothing
- **Step 6** - Pencil sketch

# %% [markdown]
# **Import Required Libraries**

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# **Importing Image**

# %%
#Original Image
image=cv2.imread("/content/puppy.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=748x421 at 0x7FBDB6DC4850>

# %% [markdown]
# **Converting Image into Grey Scale Image.**

# %%
#grey Scale Image
grey_image=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) 
cv2_imshow(grey_image)
# Out:
# <PIL.Image.Image image mode=L size=748x421 at 0x7FBDAA0C5B50>

# %% [markdown]
# **Inverting the grey scale image**

# %%
#inverted Image
inverted_image = cv2.bitwise_not(grey_image)  
cv2_imshow(inverted_image)
# Out:
# <PIL.Image.Image image mode=L size=748x421 at 0x7FBDAA0D00D0>

# %% [markdown]
# **Image Smoothing**

# %%
#image smoothing
image_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(image_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=748x421 at 0x7FBDAA0D0AD0>

# %% [markdown]
# **Pencil sketch**

# %%
def pencil_sketch(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
#pencil sketch
pencil_sketch=pencil_sketch(grey_image,image_smoothing)
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=748x421 at 0x7FBDAA0D0310>

# %% [markdown]
# **Showing Original Image and the Pencil Sketch**

# %%
cv2_imshow(image)
print("")
cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=748x421 at 0x7FBDA9028F90>
# <PIL.Image.Image image mode=L size=748x421 at 0x7FBDA9028B50>

# %% [markdown]
# **Image to Pencil Sketch with Python is done successfully!!**
